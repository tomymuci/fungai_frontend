# %%
# !unzip "Genus pictures-20221201T161832Z-001.zip"
# Out:
# Archive:  Genus pictures-20221201T161832Z-001.zip
#   inflating: Genus pictures/Hygrocybe/Hygrocybe_singeri.jpeg
#   inflating: Genus pictures/Lactarius/Lactarius_salmonicolor.jpeg
#   inflating: Genus pictures/Hygrocybe/Hygrocybe_coccinea.jpeg
#   inflating: Genus pictures/Russula/russula_virecense.jpeg
#   inflating: Genus pictures/Hygrocybe/Hygrocybe_flavescens.jpeg
#   inflating: Genus pictures/Boletus/boletus_pinicola.jpeg
#   inflating: Genus pictures/Hygrocybe/hygrocybe_splendidissima.jpeg
#   inflating: Genus pictures/Russula/Russula_torulosa.jpeg
#   inflating: Genus pictures/Lactarius/lactarius_deliciosus.jpeg
#   inflating: Genus pictures/Lactarius/Lactarius_alnicola.jpeg
#   inflating: Genus pictures/Cortinarus/cortinarius_croceus.jpeg
#   inflating: Genus pictures/Boletus/Boletus_aereus.jpeg
#   inflating: Genus pictures/Lactarius/Lactarius_aurantiacus.jpeg
#   inflating: Genus pictures/Cortinarus/Cortinarius_magellanicus.jpeg
# ...

# %%
import aspose.words as aw
import os
boletus = os.listdir()
boletus.remove("image_converter.ipynb")
boletus


doc = aw.Document()
builder = aw.DocumentBuilder(doc)
for letus in boletus:
        shape = builder.insert_image(letus)
        saveOptions = aw.saving.ImageSaveOptions(aw.SaveFormat.SVG)
        shape.get_shape_renderer().save(f'{letus.replace("jpeg","")}.svg', saveOptions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_15962/3330386750.py in <module>
#       3 boletus = os.listdir()
#       4 boletus.remove("image_converter.ipynb")
# ----> 5 boletus.remove("%.svg")
#       6 boletus
#       7
#
# ValueError: list.remove(x): x not in list

# %%
shape = builder.insert_image("Russula_torulosa.jpeg")
saveOptions = aw.saving.ImageSaveOptions(aw.SaveFormat.SVG)
shape.get_shape_renderer().save(f'{"Russula_torulosa.jpeg".replace("jpeg","")}.svg', saveOptions)

# %%
from IPython.display import SVG
SVG("Russula_torulosa..svg")

# %%
os.remove("Agaricus_bisporus.jpeg")
os.remove()

# %%
from pydrive.drive import GoogleDrive
from pydrive.auth import GoogleAuth

# For using listdir()
import os

# Below code does the authentication
# part of the code
gauth = GoogleAuth()
# Creates local webserver and auto
# handles authentication.
gauth.LocalWebserverAuth()
drive = GoogleDrive(gauth)

# replace the value of this variable
# with the absolute path of the directory


# iterating thought all the files/folder
# of the desired directory
for x in os.listdir():

    f= drive.CreateFile({'title': x})
    f.SetContentFile(x)
    f.Upload()

# Due to a known bug in pydrive if we 
# don't empty the variable used to
# upload the files to Google Drive the
# file stays open in memory and causes a
# memory leak, therefore preventing its 
# deletion
    f  = None
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/oauth2client/clientsecrets.py in _loadfile(filename)
#     120     try:
# --> 121         with open(filename, 'r') as fp:
#     122             obj = json.load(fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'client_secrets.json'
#
# During handling of the above exception, another exception occurred:
#
# InvalidClientSecretsError                 Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pydrive/auth.py in LoadClientConfigFile(self, client_config_file)
#     385     try:
# --> 386       client_type, client_info = clientsecrets.loadfile(client_config_file)
#     387     except clientsecrets.InvalidClientSecretsError as error:
#
# ...
